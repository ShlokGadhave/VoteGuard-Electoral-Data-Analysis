# %%
import pandas as pd  #importing libraries 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('fraud_flags.csv')
print(df.head(10)) #importing all the datasets
# Out:
#    voter_id  duplicate_aadhaar_flag  multi_state_flag  multiple_votes_flag  \
# 0         1                       0                 0                    0
# 1         2                       1                 0                    0
# 2         3                       1                 0                    0
# 3         4                       1                 0                    0
# 4         5                       1                 0                    0
# 5         6                       1                 0                    0
# 6         7                       0                 0                    0
# 7         8                       1                 0                    0
# 8         9                       1                 0                    0
# 9        10                       1                 0                    0
#
#    suspicious_score
# 0                 0
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...

# %%
df1=pd.read_csv('constituencies.csv')
print(df1.head())
# Out:
#    constituency_id constituency_name  district          state  \
# 0                1    Constituency_1  Tiruppur  Uttar Pradesh
# 1                2    Constituency_2    Howrah    Maharashtra
# 2                3    Constituency_3     Dehri        Gujarat
# 3                4    Constituency_4  Amravati          Delhi
# 4                5    Constituency_5    Ratlam  Uttar Pradesh
#
#    total_population
# 0            108369
# 1            438786
# 2            178393
# 3            123158
# 4            103736

# %%
df2=pd.read_csv('fraud_flags.csv')
print(df2.head(10))
# Out:
#    voter_id  duplicate_aadhaar_flag  multi_state_flag  multiple_votes_flag  \
# 0         1                       0                 0                    0
# 1         2                       1                 0                    0
# 2         3                       1                 0                    0
# 3         4                       1                 0                    0
# 4         5                       1                 0                    0
# 5         6                       1                 0                    0
# 6         7                       0                 0                    0
# 7         8                       1                 0                    0
# 8         9                       1                 0                    0
# 9        10                       1                 0                    0
#
#    suspicious_score
# 0                 0
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...

# %%
df3=pd.read_csv('voters.csv')
print(df3.head(10))
# Out:
#    voter_id        full_name  gender date_of_birth  age  aadhaar_number  \
# 0         1    Gaurangi Basu   Other    1964-11-08   61    703602471928
# 1         2     Meera Sarkar  Female    1990-10-08   35    105941298800
# 2         3      Liam Pingle   Other    1964-10-21   61    197945474067
# 3         4      Lohit Borde    Male    1984-08-20   41    542783213089
# 4         5   Hemangini Dyal  Female    1965-06-20   60    328171615853
# 5         6  Chandran Mandal  Female    1955-08-15   70    594619843437
# 6         7    Tanay Chaudry  Female    1964-02-11   61    725820745599
# 7         8        Liam Mall  Female    1953-03-06   72    337244881036
# 8         9      Gagan Setty   Other    1938-06-16   87    701507210982
# 9        10     Jack Kashyap   Other    1999-05-21   26    302655677251
#
#    phone_number                       email  \
# 0  2.544079e+09      gaurangi34@example.net
# 1  9.122859e+11        damini98@example.net
# ...

# %%
df4=pd.read_csv('voting_records.csv')
print(df4.head(10))
# Out:
#    vote_id  voter_id  station_id   vote_date
# 0        1         1          19  2024-04-01
# 1        2         5         174  2024-04-01
# 2        3         6          32  2024-04-01
# 3        4         8          64  2024-04-01
# 4        5         9          99  2024-04-01
# 5        6        10          24  2024-04-01
# 6        7        12          27  2024-04-01
# 7        8        15          97  2024-04-01
# 8        9        17          78  2024-04-01
# 9       10        18         142  2024-04-01

# %%
#identifying types and shape of each datasets 
df.dtypes
# Out:
# voter_id                  int64
# duplicate_aadhaar_flag    int64
# multi_state_flag          int64
# multiple_votes_flag       int64
# suspicious_score          int64
# dtype: object

# %%
df1.dtypes
# Out:
# constituency_id       int64
# constituency_name    object
# district             object
# state                object
# total_population      int64
# dtype: object

# %%
df2.dtypes
# Out:
# voter_id                  int64
# duplicate_aadhaar_flag    int64
# multi_state_flag          int64
# multiple_votes_flag       int64
# suspicious_score          int64
# dtype: object

# %%
df3.dtypes
# Out:
# voter_id               int64
# full_name             object
# gender                object
# date_of_birth         object
# age                    int64
# aadhaar_number         int64
# phone_number         float64
# email                 object
# address               object
# city                  object
# district              object
# state                 object
# pincode                int64
# registration_date     object
# dtype: object

# %%
df4.dtypes
# Out:
# vote_id        int64
# voter_id       int64
# station_id     int64
# vote_date     object
# dtype: object

# %%
#idenitifying shape of datasets
df.shape
# Out:
# (5000, 5)

# %%
df1.shape
# Out:
# (50, 5)

# %%
df2.shape
# Out:
# (5000, 5)

# %%
df3.shape
# Out:
# (5000, 14)

# %%
df4.shape
# Out:
# (4396, 4)

# %%
#Display statistical data of numerical column 
df.describe()
# Out:
#           voter_id  duplicate_aadhaar_flag  multi_state_flag  \
# count  5000.000000             5000.000000       5000.000000
# mean   2500.500000                0.666400          0.034200
# std    1443.520003                0.471546          0.181761
# min       1.000000                0.000000          0.000000
# 25%    1250.750000                0.000000          0.000000
# 50%    2500.500000                1.000000          0.000000
# 75%    3750.250000                1.000000          0.000000
# max    5000.000000                1.000000          1.000000
#
#        multiple_votes_flag  suspicious_score
# count           5000.00000        5000.00000
# mean               0.08000           0.78060
# std                0.27132           0.57596
# min                0.00000           0.00000
# 25%                0.00000           0.00000
# 50%                0.00000           1.00000
# 75%                0.00000           1.00000
# max                1.00000           3.00000

# %%
df1.describe()
# Out:
#        constituency_id  total_population
# count         50.00000         50.000000
# mean          25.50000     277461.980000
# std           14.57738     136921.429511
# min            1.00000      63912.000000
# 25%           13.25000     143355.750000
# 50%           25.50000     293079.500000
# 75%           37.75000     398704.500000
# max           50.00000     484846.000000

# %%
df2.describe()
# Out:
#           voter_id  duplicate_aadhaar_flag  multi_state_flag  \
# count  5000.000000             5000.000000       5000.000000
# mean   2500.500000                0.666400          0.034200
# std    1443.520003                0.471546          0.181761
# min       1.000000                0.000000          0.000000
# 25%    1250.750000                0.000000          0.000000
# 50%    2500.500000                1.000000          0.000000
# 75%    3750.250000                1.000000          0.000000
# max    5000.000000                1.000000          1.000000
#
#        multiple_votes_flag  suspicious_score
# count           5000.00000        5000.00000
# mean               0.08000           0.78060
# std                0.27132           0.57596
# min                0.00000           0.00000
# 25%                0.00000           0.00000
# 50%                0.00000           1.00000
# 75%                0.00000           1.00000
# max                1.00000           3.00000

# %%
df3.describe()
# Out:
#           voter_id          age  aadhaar_number  phone_number        pincode
# count  5000.000000  5000.000000    5.000000e+03  4.479000e+03    5000.000000
# mean   2500.500000    53.550200    5.558059e+11  3.011840e+11  496867.944600
# std    1443.520003    21.041094    2.563601e+11  4.264923e+11  287774.488197
# min       1.000000    17.000000    1.008712e+11  8.805886e+06     372.000000
# 25%    1250.750000    36.000000    3.416294e+11  3.636571e+09  248083.000000
# 50%    2500.500000    53.000000    5.603200e+11  7.232670e+09  500557.000000
# 75%    3750.250000    72.000000    7.734668e+11  9.123861e+11  741183.000000
# max    5000.000000    90.000000    9.999630e+11  9.199997e+11  999405.000000

# %%
df4.describe()
# Out:
#            vote_id     voter_id   station_id
# count  4396.000000  4396.000000  4396.000000
# mean   2198.500000  2503.158326   101.314149
# std    1269.160221  1443.235648    57.958969
# min       1.000000     1.000000     1.000000
# 25%    1099.750000  1251.000000    51.000000
# 50%    2198.500000  2514.000000   102.000000
# 75%    3297.250000  3744.000000   153.000000
# max    4396.000000  5000.000000   200.000000
